# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %%
# get todays date
current_date = datetime.today().strftime('%m-%d-%Y')
yesterdays_date = (datetime.today() - timedelta(days=1)).strftime('%m-%d-%Y')

# %%
try:
    daily_report = pd.read_csv(f'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/{current_date}.csv')
except:
    daily_report = pd.read_csv(f'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/{yesterdays_date}.csv')

# %%
daily_report.head()
# Out:
#   Province/State  Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2020-02-27T12:13:14      65596    2641
# 1            NaN     South Korea  2020-02-27T12:03:04       1766      13
# 2      Guangdong  Mainland China  2020-02-27T09:53:02       1347       7
# 3          Henan  Mainland China  2020-02-27T15:03:11       1272      20
# 4       Zhejiang  Mainland China  2020-02-27T12:43:02       1205       1
#
#    Recovered
# 0      23383
# 1         22
# 2        890
# 3       1068
# 4        932

# %%
# get stats grouped by country
groupby_country = daily_report.drop(['Province/State','Last Update'] ,axis=1)
groupby_country = groupby_country[['Confirmed','Deaths','Recovered']].groupby(groupby_country['Country/Region'])
groupby_country = groupby_country.sum()
groupby_country
# Out:
#                       Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan                   1       0          0
# Algeria                       1       0          0
# Australia                    23       0         11
# Austria                       3       0          0
# Bahrain                      33       0          0
# Belgium                       1       0          1
# Brazil                        1       0          0
# Cambodia                      1       0          1
# Canada                       13       0          6
# Croatia                       3       0          0
# Denmark                       1       0          0
# Egypt                         1       0          0
# Estonia                       1       0          0
# Finland                       2       0          1
# France                       38       2         11
# Georgia                       1       0          0
# Germany                      46       0         16
# ...

# %%
# calculate recovery and death rates
groupby_country['Death Rate'] =  groupby_country.apply(lambda row: (row.Deaths/row.Confirmed), axis=1)
groupby_country['Recovery Rate'] =  groupby_country.apply(lambda row: (row.Recovered/row.Confirmed), axis=1)
groupby_country
# Out:
#                       Confirmed  Deaths  Recovered  Death Rate  Recovery Rate
# Country/Region
# Afghanistan                   1       0          0    0.000000       0.000000
# Algeria                       1       0          0    0.000000       0.000000
# Australia                    23       0         11    0.000000       0.478261
# Austria                       3       0          0    0.000000       0.000000
# Bahrain                      33       0          0    0.000000       0.000000
# Belgium                       1       0          1    0.000000       1.000000
# Brazil                        1       0          0    0.000000       0.000000
# Cambodia                      1       0          1    0.000000       1.000000
# Canada                       13       0          6    0.000000       0.461538
# Croatia                       3       0          0    0.000000       0.000000
# Denmark                       1       0          0    0.000000       0.000000
# ...

# %%
# aggregated death and recovery rates
aggregated_raw_data = groupby_country[['Confirmed','Deaths','Recovered']].sum()
aggregated_processed_data = groupby_country[['Death Rate','Recovery Rate']].mean()
aggregated_data = aggregated_raw_data.append(aggregated_processed_data)
aggregated_data.to_frame()
# Out:
#                           0
# Confirmed      82756.000000
# Deaths          2814.000000
# Recovered      33277.000000
# Death Rate         0.012032
# Recovery Rate      0.280222

# %%
#
